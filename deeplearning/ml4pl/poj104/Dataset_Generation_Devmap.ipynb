# %% [markdown]
# # Dataset generation: ProGraML x Devmap <a class='tocSkip'>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Configs" data-toc-modified-id="Configs-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Configs</a></span></li><li><span><a href="#Dev:-Helper-Functions" data-toc-modified-id="Dev:-Helper-Functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Dev: Helper Functions</a></span><ul class="toc-item"><li><span><a href="#Dev:-nx2data-(more-flexible!)" data-toc-modified-id="Dev:-nx2data-(more-flexible!)-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Dev: nx2data (more flexible!)</a></span></li></ul></li><li><span><a href="#Main" data-toc-modified-id="Main-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Main</a></span><ul class="toc-item"><li><span><a href="#needs-action:" data-toc-modified-id="needs-action:-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span><em>needs action:</em></a></span></li><li><span><a href="#Process-devmap-.ll-files-(from-NCC-release)" data-toc-modified-id="Process-devmap-.ll-files-(from-NCC-release)-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Process devmap .ll files (from NCC release)</a></span></li><li><span><a href="#fetch-labels-etc.-from-csv" data-toc-modified-id="fetch-labels-etc.-from-csv-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>fetch labels etc. from csv</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Configs

# %%
# Set editor width to something sane
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
# get root repository path
a = !pwd
REPO_ROOT = a[0].rsplit('ProGraML', maxsplit=1,)[0] + 'ProGraML'
print(REPO_ROOT)
#insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, REPO_ROOT)
# Out:
# /home/zacharias/ProGraML

# %%
from pathlib import Path
import pickle

import numpy as np
from matplotlib import pyplot as plt
import networkx as nx
import tqdm
import torch
from torch_geometric.data import Data, DataLoader, InMemoryDataset
import torch_geometric

# %%
#from google.protobuf import text_format
#from deeplearning.ml4pl.graphs import programl
#from deeplearning.ml4pl.graphs.labelled import graph_tuple
#from labm8.py import app

# %%
from deeplearning.ml4pl.graphs.unlabelled.llvm2graph import graph_builder

builder = graph_builder.ProGraMLGraphBuilder()

# %% [markdown]
# # Dev: Helper Functions
# `
# unreachable,232
# ret void,263
# !UNK,8564
# !IDENTIFIER, 8565
# magic/root/ I forgot, 8567
# `

# %%
#nx_graph = builder.Build(ll)

# %% [markdown]
# ## Dev: nx2data (more flexible!)

# %%
def nx2data(nx_graph, class_label=None):
    r"""Converts a :obj:`networkx.Graph` or :obj:`networkx.DiGraph` to a
    :class:`torch_geometric.data.Data` instance.

    Args:
        G (networkx.Graph or networkx.DiGraph): A networkx graph.
    """

    # make sure the nx_graph is encoded properly (since node.x used to be buggy!)
    # encoder = GraphNodeEncoder()
    # encoder.EncodeNodes(nx_graph)

    # collect edge_index
    edge_index = torch.tensor(list(nx_graph.edges())).t().contiguous()

    # collect edge_attr
    positions = []
    flows = []

    for i, (_, _, edge_data) in enumerate(nx_graph.edges(data=True)):
        positions.append(edge_data['position'])
        flows.append(edge_data['flow'])

    positions = torch.tensor(positions)
    flows = torch.tensor(flows)

    edge_attr = torch.cat([flows, positions]).view(2, -1).t().contiguous()
    
    # collect x
    types = []
    xs = []
    
    for i, node_data in nx_graph.nodes(data=True):
        types.append(node_data['type'])
        xs.append(node_data['x'][0])

    xs = torch.tensor(xs)
    types = torch.tensor(types)
    
    x = torch.cat([xs, types]).view(2, -1).t().contiguous()

    
    assert edge_attr.size()[0] == edge_index.size()[1], f'edge_attr={edge_attr.size()} size mismatch with edge_index={edge_index.size()}'
    
    if class_label is not None:
        y = torch.tensor(int(class_label)).view(1)  # <1>
        data = Data(x=x, edge_index=edge_index, edge_attr=edge_attr, y=y)
    else:
        data = Data(x=x, edge_index=edge_index, edge_attr=edge_attr)
    
    return data

# %%
from multiprocessing import Pool
import tqdm
import os

def dump(outfile, data, mkdir=True):
    if mkdir:
        outfile.parent.mkdir(exist_ok=True, parents=True)
    with open(outfile, 'wb') as f:
        pickle.dump(data, f)

def load(file):
    with open(file, 'rb') as f:
        data = pickle.load(f)
    return data

# %%
def process_single_folder(folder, dump_nx=True, dump_data=True):    
    problems = ""
    out_base = folder.parent
    
    print(f"=== Opening Folder {str(folder)} ===")
    
    #label = int(folder.name)
    # TODO: generate labels!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    label = None
    
    
    files = list(folder.glob('*.ll'))
    
    # iterate over all .ll files in folder and confirm and respectively create the .nx.p and .data.p files
    for i, file in enumerate(files):
        outfile_nx = out_base / (folder.name + '_programl') / '_nx' / (file.name.rsplit('.', 1)[0] + '.nx.p')
        outfile_data = out_base / (folder.name + '_programl') / (file.name.rsplit('.', 1)[0] + '.data.p')

        # find out where to start processing

        # skip entirely?
        if outfile_data.is_file():
            continue

        # start at step 2: nx --> data ?
        if outfile_nx.is_file():
            nx_graph = load(outfile_nx)            
            data = nx2data(nx_graph, class_label=label)
            dump(outfile_data, data)
            continue
        
        # start in the beginning:
        # ~~~ step 1: .ll --> nx ~~~
        if i % 100 == 0:
            print(f"{folder.name} - [{i}/{len(files)}] Processing {str(file)} ...")
        
        with open(file, 'r') as f:
            bytecode = f.read()

        try:
            nx_graph = builder.Build(bytecode) # nx
            if dump_nx:
                dump(outfile_nx, nx_graph)
        except:
            print(f"***** FAILING ON {str(file)} ... renaming file to .ll_ ")
            problems += str(file)
            problems += '\n'
            file.rename(file.with_suffix('.ll_'))
            continue

        # step 2: nx --> data
        data = nx2data(nx_graph, class_label=label)
        dump(outfile_data, data)

    return problems

# %%
# download dataset if needed (this is for classifyapp!)
import wget
import zipfile

def download_and_unzip(url, dataset_name, data_folder):
    """
    Download and unzip data set folder from url
    :param url: from which to download
    :param dataset_name: name of data set (for printing)
    :param data_folder: folder in which to put the downloaded data
    """
    print('Downloading', dataset_name, 'data set...')
    if not os.path.exists(data_folder):
        os.makedirs(data_folder)
    data_zip = wget.download(url, out=data_folder)
    print('\tunzipping...')
    zip_ = zipfile.ZipFile(data_zip, 'r')
    assert os.path.isdir(data_folder), data_folder
    zip_.extractall(data_folder)
    zip_.close()
    print('\tdone')

def download_classifyapp(dataset_path):
    # get Path object
    if type(dataset_path) == str:
        dataset_path = Path(dataset_path)
    dataset_path = dataset_path / 'classifyapp_data'
        
    # Acquire data
    if not dataset_path.exists():
        dataset_path.mkdir(parents=True)
        download_and_unzip('https://polybox.ethz.ch/index.php/s/JOBjrfmAjOeWCyl/download',
                                      'classifyapp_data', str(dataset_path.absolute()))
    else:
        print(f'skipped downloading to {str(dataset_path.absolute())}')

# %% [markdown]
# # Main
# ## *needs action:*

# %%
# !pwd
# Out:
# /home/zacharias/ProGraML/deeplearning/ml4pl/poj104

# %%
# Set where to store the dataset and download automagically
ds_basepath = Path('/mnt/data/llvm/master_thesis_datasets')

# uncomment this line to save data "in place"
#ds_basepath = Path(repo_root) / 'deeplearning/ml4pl/poj104'

logs_basepath = ds_basepath / 'logs' / 'devmap_logs'

ds_basepath.mkdir(parents=True, exist_ok=True)
logs_basepath.mkdir(parents=True, exist_ok=True)

#download_classifyapp(ds_basepath)

# %%
# link those places into poj104 folder

data_source = str((ds_basepath / 'devmap_data').absolute())
print(data_source)
data_target = REPO_ROOT + '/deeplearning/ml4pl/poj104/'
print(data_target)

logs_source = str(logs_basepath.absolute())
print(logs_source)
logs_target = REPO_ROOT + '/deeplearning/ml4pl/poj104/'
print(logs_target)
# Out:
# /mnt/data/llvm/master_thesis_datasets/devmap_data
# /home/zacharias/ProGraML/deeplearning/ml4pl/poj104/
# /mnt/data/llvm/master_thesis_datasets/logs/devmap_logs
# /home/zacharias/ProGraML/deeplearning/ml4pl/poj104/

# %%
! ln -s {data_source} {data_target}
! ln -s {logs_source} {logs_target}
! ls -lah {str(REPO_ROOT + '/deeplearning/ml4pl/poj104')} | grep devmap
# Out:
# ln: failed to create symbolic link '/home/zacharias/ProGraML/deeplearning/ml4pl/poj104/devmap_data': File exists
# ln: failed to create symbolic link '/home/zacharias/ProGraML/deeplearning/ml4pl/poj104/devmap_logs': File exists
# lrwxrwxrwx  1 zacharias zacharias   49 Feb  1 19:30 devmap_data -> /mnt/data/llvm/master_thesis_datasets/devmap_data
# lrwxrwxrwx  1 zacharias zacharias   54 Feb  1 19:31 devmap_logs -> /mnt/data/llvm/master_thesis_datasets/logs/devmap_logs

# %% [markdown]
# ## Process devmap .ll files (from NCC release)

# %%
# start processing the smaller validation dataset
data_source = Path(data_source)
dataset_path = data_source / 'kernels_ir'
print(dataset_path.name)
print(dataset_path)
# Out:
# kernels_ir
# /mnt/data/llvm/master_thesis_datasets/devmap_data/kernels_ir

# %%
process_single_folder(dataset_path)
# Out:
# === Opening Folder /mnt/data/llvm/master_thesis_datasets/devmap_data/kernels_ir ===
# ''

# %% [markdown]
# ## fetch labels etc. from csv

# %%
import pandas as pd

platform = 'amd'

# Load runtime data
data_file = data_source / f"cgo17-{platform}.csv"
print('\n--- Read data from', data_file)
df = pd.read_csv(data_file)

# %%
df
# Out:
#      Unnamed: 0                                          benchmark  dataset  \
# 0             0    amd-app-sdk-3.0-BinomialOption-binomial_options  default
# 1             1            amd-app-sdk-3.0-BitonicSort-bitonicSort  default
# 2             2          amd-app-sdk-3.0-BlackScholes-blackScholes  default
# 3             3  amd-app-sdk-3.0-FastWalshTransform-fastWalshTr...  default
# 4             4    amd-app-sdk-3.0-FloydWarshall-floydWarshallPass  default
# 5             5     amd-app-sdk-3.0-MatrixMultiplication-mmmKernel  default
# 6             6    amd-app-sdk-3.0-MatrixTranspose-matrixTranspose  default
# 7             7          amd-app-sdk-3.0-PrefixSum-group_prefixSum  default
# 8             8                   amd-app-sdk-3.0-Reduction-reduce  default
# 9             9    amd-app-sdk-3.0-ScanLargeArrays-ScanLargeArrays  default
# 10           10      amd-app-sdk-3.0-ScanLargeArrays-blockAddition  default
# 11           11          amd-app-sdk-3.0-ScanLargeArrays-prefixSum  default
# 12           12  amd-app-sdk-3.0-SimpleConvolution-simpleNonSep...  default
# 13           13  amd-app-sdk-3.0-SimpleConvolution-simpleSepara...  default
# 14           14  amd-app-sdk-3.0-SimpleConvolution-simpleSepara...  default
# 15           15           amd-app-sdk-3.0-SobelFilter-sobel_filter  default
# 16           16                                     npb-3.3-BT-add        A
# 17           17                                     npb-3.3-BT-add        B
# 18           18                                     npb-3.3-BT-add        S
# 19           19                                     npb-3.3-BT-add        W
# 20           20                            npb-3.3-BT-compute_rhs1        A
# 21           21                            npb-3.3-BT-compute_rhs1        B
# 22           22                            npb-3.3-BT-compute_rhs1        S
# 23           23                            npb-3.3-BT-compute_rhs1        W
# 24           24                            npb-3.3-BT-compute_rhs2        A
# 25           25                            npb-3.3-BT-compute_rhs2        B
# 26           26                            npb-3.3-BT-compute_rhs2        S
# 27           27                            npb-3.3-BT-compute_rhs2        W
# 28           28                            npb-3.3-BT-compute_rhs3        A
# 29           29                            npb-3.3-BT-compute_rhs3        B
# ..          ...                                                ...      ...
# 650         650                        shoc-1.1.5-S3D-ratt6_kernel  default
# 651         651                        shoc-1.1.5-S3D-ratt7_kernel  default
# 652         652                        shoc-1.1.5-S3D-ratt8_kernel  default
# 653         653                        shoc-1.1.5-S3D-ratt9_kernel  default
# 654         654                         shoc-1.1.5-S3D-ratt_kernel  default
# 655         655                        shoc-1.1.5-S3D-ratx2_kernel  default
# 656         656                        shoc-1.1.5-S3D-ratx4_kernel  default
# 657         657                         shoc-1.1.5-S3D-ratx_kernel  default
# 658         658                        shoc-1.1.5-S3D-ratxb_kernel  default
# 659         659                        shoc-1.1.5-S3D-rdsmh_kernel  default
# 660         660                     shoc-1.1.5-S3D-rdwdot10_kernel  default
# 661         661                      shoc-1.1.5-S3D-rdwdot2_kernel  default
# 662         662                      shoc-1.1.5-S3D-rdwdot3_kernel  default
# 663         663                      shoc-1.1.5-S3D-rdwdot6_kernel  default
# 664         664                      shoc-1.1.5-S3D-rdwdot7_kernel  default
# 665         665                      shoc-1.1.5-S3D-rdwdot8_kernel  default
# 666         666                      shoc-1.1.5-S3D-rdwdot9_kernel  default
# 667         667                       shoc-1.1.5-S3D-rdwdot_kernel  default
# 668         668                        shoc-1.1.5-Scan-bottom_scan  default
# 669         669                             shoc-1.1.5-Scan-reduce  default
# 670         670                           shoc-1.1.5-Scan-top_scan  default
# 671         671                        shoc-1.1.5-Sort-bottom_scan  default
# 672         672                             shoc-1.1.5-Sort-reduce  default
# 673         673                           shoc-1.1.5-Sort-top_scan  default
# 674         674             shoc-1.1.5-Spmv-spmv_csr_scalar_kernel  default
# 675         675             shoc-1.1.5-Spmv-spmv_csr_vector_kernel  default
# 676         676               shoc-1.1.5-Spmv-spmv_ellpackr_kernel  default
# 677         677                      shoc-1.1.5-Stencil2D-CopyRect  default
# 678         678                 shoc-1.1.5-Stencil2D-StencilKernel  default
# 679         679                             shoc-1.1.5-Triad-Triad  default
#
#      comp  rational  mem  localmem  coalesced  atomic    transfer  wgsize  \
# 0      98         8   13        11          2       0        2048     255
# 1      12         2    6         0          6       0      131072     256
# 2     220         4    3         0          0       0     3145728     256
# 3       8         0    4         0          4       0        4096     256
# 4      11         1    5         0          0       0      524288     256
# 5     163         1   12         0          0       0       49152      64
# 6      42         0   16         8          2       0       32768     256
# 7      36        10   12         8          2       0        4096     640
# 8       6         3    7         4          2       0        8208     256
# 9      32         3   21        14          4       0      263168     128
# 10      0         1    4         2          2       0      263168     256
# 11     31         3   19        13          3       0      263168      64
# 12      9         4    3         0          3       0     4206668     256
# 13      9         3    3         0          1       0     4206668     256
# 14      7         3    3         0          1       0     4206668     256
# 15     31         4   10         0          4       0     2097152     256
# 16     28         4    2         0          3       0   320457304      62
# 17     28         4    2         0          3       0  1313675032      32
# 18     28         4    2         0          3       0     1807992      60
# 19     28         4    2         0          3       0    15948384      44
# 20    127         3    8         0         12       0   320457304      64
# 21    127         3    8         0         12       0  1313675032      32
# 22    127         3    8         0         12       0     1807992      60
# 23    127         3    8         0         12       0    15948384      48
# 24     27         4    2         0          2       0   320457304      64
# 25     27         4    2         0          2       0  1313675032      32
# 26     27         4    2         0          2       0     1807992      60
# 27     27         4    2         0          2       0    15948384      48
# 28   1257        23    8         0        107       0   320454224      62
# 29   1257        23    8         0        107       0  1313675032      32
# ..    ...       ...  ...       ...        ...     ...         ...     ...
# 650   587         0  148         0          0       0    57594120     128
# 651   579         0  146         0          0       0    57594120     128
# 652   587         0  148         0          0       0    57594120     128
# 653   746         0  189         0          0       0    57594120     128
# 654  2650         0  207         0          0       0    57594120     128
# 655  2294         0  669         0          0       0    57594120     128
# 656  2426         0  702         0          0       0    57594120     128
# 657  1201         1   98         0          0       0    57594120     128
# 658  1321         1  163         0          0       0    57594120     128
# 659  1878         1   63         0          0       0    57594120     128
# 660  1072         0  272         0          4       0    57594120     128
# 661   267         0   69         0          2       0    57594120     128
# 662   948         0  244         0          7       0    57594120     128
# 663   416         0  106         0          2       0    57594120     128
# 664   576         0  146         0          2       0    57594120     128
# 665   411         0  104         0          2       0    57594120     128
# 666   492         0  124         0          1       0    57594120     128
# 667   693         0  174         0          1       0    57594120     128
# 668    13         6   12         5          2       0     8389376     256
# 669    10         5    6         4          1       0     8389376     256
# 670     2         3    8         5          0       0     8389376     256
# 671    27        10   24        16          5       0     4198400     256
# 672    14         6    6         4          1       0     4198400     256
# 673     9         6   11         5          0       0     4198400     256
# 674     2         2    6         0          6       0     2000628     128
# 675    12         5   11         5          6       0     2000628     128
# 676     3         2    5         0          5       0     2000628     128
# 677     8         2    2         0          0       0    71647488       0
# 678   144         7   16        12          3       0    71647488     256
# 679     2         0    3         0          3       0   117440512     128
#
#     oracle  runtime_cpu  runtime_gpu  \
# 0      GPU     3.291073     1.443983
# 1      CPU     0.121940     0.279521
# 2      GPU     6.076052     2.740855
# 3      CPU     0.130003     0.668892
# 4      CPU     0.283447     0.769755
# 5      CPU     0.277644     1.120132
# 6      CPU     0.156639     1.009519
# 7      CPU     0.484234     0.847908
# 8      CPU     0.161025     0.887437
# 9      CPU     0.336185     0.793181
# 10     CPU     0.147294     0.434674
# 11     CPU     0.130323     0.474609
# 12     GPU     3.979828     3.092223
# 13     GPU     3.226918     2.856623
# 14     GPU     3.256935     3.022480
# 15     GPU     3.535082     2.655104
# 16     GPU     1.880737     1.302612
# 17     GPU     7.096428     1.966463
# 18     CPU     0.079557     9.861878
# 19     CPU     0.145375     0.575309
# 20     GPU     2.088552     1.090927
# 21     GPU     9.072222     1.760085
# 22     CPU     0.082590     9.855946
# 23     CPU     0.175005     0.573140
# 24     GPU     2.059176     1.075332
# 25     GPU     7.506122     1.447829
# 26     CPU     0.081181     9.849159
# 27     CPU     0.159460     0.568107
# 28     CPU     2.858859     2.865368
# 29     GPU    11.403199     8.557004
# ..     ...          ...          ...
# 650    CPU     6.321418    13.149482
# 651    CPU     6.301249    13.153888
# 652    CPU     6.285722    13.137571
# 653    CPU     6.472397    13.141964
# 654    CPU     8.545337    14.104563
# 655    GPU    14.384527    13.746262
# 656    GPU    14.887798    13.734100
# 657    CPU     8.655694    13.826373
# 658    CPU     8.440195    13.742532
# 659    CPU     6.483252    13.388218
# 660    CPU     6.978079    13.452854
# 661    CPU     5.994753    13.078233
# 662    CPU     7.038685    13.403108
# 663    CPU     6.107217    13.149065
# 664    CPU     6.325321    13.182723
# 665    CPU     6.207221    13.133875
# 666    CPU     6.276553    13.178223
# 667    CPU     6.726004    13.339326
# 668    GPU     4.931584     3.437920
# 669    GPU     4.170566     3.426097
# 670    GPU     4.011485     3.415707
# 671    GPU    17.005040     2.007888
# 672    GPU     4.338501     1.869492
# 673    GPU     1.885541     1.863657
# 674    CPU     2.038006     6.981001
# 675    CPU     2.036940     6.951909
# 676    CPU     2.035003     6.998864
# 677    GPU    17.328426    16.666277
# 678    GPU    17.866730    16.666380
# 679    CPU   876.457180   968.494606
#
#                                                    src  \
# 0    __kernel void A(int a, const __global float4* ...
# 1    __kernel void A(__global uint* a, const uint b...
# 2    __kernel void A(const __global float4* a, int ...
# 3    __kernel void A(__global float* a, __const int...
# 4    __kernel void A(__global uint* a, __global uin...
# 5    __kernel void A(__global float4* a, __global f...
# 6    __kernel void A(__global float4* a, __global f...
# 7    __kernel void A(__global float* a, __global fl...
# 8    __kernel void A(__global uint4* a, __global ui...
# 9    __kernel void A(__global float* a, __global fl...
# 10   __kernel void A(__global float* a, __global fl...
# 11   __kernel void A(__global float* a, __global fl...
# 12   __kernel void A(__global uint* a, __global flo...
# 13   __kernel void A(__global uint* a, __global flo...
# 14   __kernel void A(__global float* a, __global fl...
# 15   __kernel void A(__global uchar4* a, __global u...
# 16   __kernel void A(__global double* a, __global d...
# 17   __kernel void A(__global double* a, __global d...
# 18   __kernel void A(__global double* a, __global d...
# 19   __kernel void A(__global double* a, __global d...
# 20   __kernel void A(__global const double* a, __gl...
# 21   __kernel void A(__global const double* a, __gl...
# 22   __kernel void A(__global const double* a, __gl...
# 23   __kernel void A(__global const double* a, __gl...
# 24   __kernel void A(__global const double* a, __gl...
# 25   __kernel void A(__global const double* a, __gl...
# 26   __kernel void A(__global const double* a, __gl...
# 27   __kernel void A(__global const double* a, __gl...
# 28   __kernel void A(__global const double* a, __gl...
# 29   __kernel void A(__global const double* a, __gl...
# ..                                                 ...
# 650  __kernel void A(__global const float* a, __glo...
# 651  __kernel void A(__global const float* a, __glo...
# 652  __kernel void A(__global const float* a, __glo...
# 653  __kernel void A(__global const float* a, __glo...
# 654  __kernel void A(__global const float* a, __glo...
# 655  __kernel void A(__global const float* a, __glo...
# 656  __kernel void A(__global const float* a, __glo...
# 657  __kernel void A(__global const float* a, __glo...
# 658  __kernel void A(__global const float* a, __glo...
# 659  __kernel void A(__global const float* a, __glo...
# 660  __kernel void A(__global const float* a, __glo...
# 661  __kernel void A(__global const float* a, __glo...
# 662  __kernel void A(__global const float* a, __glo...
# 663  __kernel void A(__global const float* a, __glo...
# 664  __kernel void A(__global const float* a, __glo...
# 665  __kernel void A(__global const float* a, __glo...
# 666  __kernel void A(__global const float* a, __glo...
# 667  __kernel void A(__global const float* a, __glo...
# 668  __kernel void A(__global const float* a, __glo...
# 669  __kernel void A(__global const float* a, __glo...
# 670  __kernel void A(__global float* a, const int b...
# 671  __kernel void A(__global const uint* a, __glob...
# 672  __kernel void A(__global const uint* a, __glob...
# 673  __kernel void A(__global uint* a, const int b,...
# 674  __kernel void A(__global const float* restrict...
# 675  __kernel void A(__global const float* restrict...
# 676  __kernel void A(__global const float* restrict...
# 677  __kernel void A(__global float* a, int b, int ...
# 678  __kernel void A(__global float* a, __global fl...
# 679  __kernel void A(__global const float* a, __glo...
#
#                                 seq
# 0    [129 129 129 ...,   0 127   0]
# 1    [129 129 129 ...,   0 127   0]
# 2    [129 129 129 ...,  26   0 127]
# 3    [129 129 129 ...,   0 127   0]
# 4    [129 129 129 ..., 127   0 127]
# 5    [  1   9   1 ...,   0 127   0]
# 6    [129 129 129 ...,   0 127   0]
# 7    [129 129 129 ...,   0 127   0]
# 8    [129 129 129 ...,   0 127   0]
# 9    [129 129 129 ..., 127   0 127]
# 10   [129 129 129 ...,  26   0 127]
# 11   [129 129 129 ..., 127   0 127]
# 12   [129 129 129 ...,  26   0 127]
# 13   [129 129 129 ...,  26   0 127]
# 14   [129 129 129 ...,  26   0 127]
# 15   [129 129 129 ...,   0 127   0]
# 16   [129 129 129 ..., 127   0 127]
# 17   [129 129 129 ..., 127   0 127]
# 18   [129 129 129 ..., 127   0 127]
# 19   [129 129 129 ..., 127   0 127]
# 20   [  1  93   1 ...,   0 127   0]
# 21   [  1  93   1 ...,   0 127   0]
# 22   [  1  93   1 ...,   0 127   0]
# 23   [  1  93   1 ...,   0 127   0]
# 24   [129 129 129 ..., 127   0 127]
# 25   [129 129 129 ..., 127   0 127]
# 26   [129 129 129 ..., 127   0 127]
# 27   [129 129 129 ..., 127   0 127]
# 28   [ 17   1  12 ..., 127   0 127]
# 29   [ 17   1  12 ..., 127   0 127]
# ..                              ...
# 650  [ 23   8   8 ...,   0 127   0]
# 651  [ 15   8   8 ...,   0 127   0]
# 652  [  1   9   1 ...,   0 127   0]
# 653  [  7  73  51 ...,   0 127   0]
# 654  [ 13  20  76 ...,   0 127   0]
# 655  [ 65  51   7 ...,   0 127   0]
# 656  [ 65  51   7 ...,   0 127   0]
# 657  [ 52   8   1 ...,   0 127   0]
# 658  [  1  17  13 ...,   0 127   0]
# 659  [ 18  78   1 ..., 127   0 127]
# 660  [  8  52   8 ...,   0 127   0]
# 661  [  7   7  16 ...,   0 127   0]
# 662  [  2   2   2 ...,   0 127   0]
# 663  [ 51   7   7 ...,   0 127   0]
# 664  [ 51   7   7 ...,   0 127   0]
# 665  [ 12   1  16 ...,   0 127   0]
# 666  [  1   7  65 ...,   0 127   0]
# 667  [  7   7   7 ...,   0 127   0]
# 668  [129 129 129 ..., 127   0 127]
# 669  [129 129 129 ..., 127   0 127]
# 670  [129 129 129 ..., 127   0 127]
# 671  [ 15  11   1 ..., 127   0 127]
# 672  [129 129 129 ..., 127   0 127]
# 673  [129 129 129 ..., 127   0 127]
# 674  [129 129 129 ..., 127   0 127]
# 675  [129 129 129 ..., 127   0 127]
# 676  [129 129 129 ..., 127   0 127]
# 677  [129 129 129 ..., 127   0 127]
# 678  [  1  96   1 ..., 127   0 127]
# 679  [129 129 129 ...,   0 127   0]
#
# [680 rows x 16 columns]

# %%
# Get list of source file names
#data_folder = os.path.join(data_folder, 'kernels_seq')
input_files = df["benchmark"].values   # list of strings of benchmark names
dataset = df["dataset"].values         # list of strings of dataset descriptions
aux_transfer_size = df["transfer"].values
aux_wg_size = df["wgsize"].values
oracle = df['oracle'].values
runtime_cpu = df['runtime_cpu'].values
runtime_gpu = df['runtime_gpu'].values



num_files = len(input_files)
print('\n--- Preparing to read', num_files, 'input files')
# Out:
# --- Preparing to read 680 input files

# %%
# Out:
# str

# %%
import tqdm
import pickle

# %%
torch.tensor(runtime_cpu[0]).dtype
# Out:
# torch.float32

# %%
data_list = []
for i in tqdm.tqdm(range(num_files)):
    filename = input_files[i]
    dat = dataset[i]
    if filename[:3] == "npb":
        # concatenate data set size
        filename += '_' + str(dat)
        
    file = data_source / 'kernels_ir_programl' / (filename + '.data.p')
    if file.exists():
        # load preprocessed torch_geometric.data.Data
        with open(file, 'rb') as f:
            data = pickle.load(f)
    else:
        assert False, f'input file not found: {str(file)}'
    
    # add data
    data['y'] = torch.tensor(1) if oracle[i] == 'GPU' else torch.tensor(0)
    data['aux_in'] = torch.tensor([aux_transfer_size[i], aux_wg_size[i]])
    data['runtime'] = torch.tensor([runtime_cpu[i], runtime_gpu[i]])
    
    data_list.append(data)
    dump(file, data)
# Out:
# 100%|██████████| 680/680 [00:00<00:00, 1493.66it/s]

# %%
data
# Out:
# Data(aux_in=[2], edge_attr=[46, 2], edge_index=[2, 46], runtime=[2], x=[33, 2], y=[])
